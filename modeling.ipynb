# %%
import pandas as pd
import numpy as np
import altair as alt
import re
import statsmodels as sm
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.feature_selection import VarianceThreshold

# %%
data = pd.read_csv('./data/TrainingSet.csv', index_col=0)
submission_rows = pd.read_csv('./data/SubmissionRows.csv', index_col=0)

# %%
def clean_up_year_columns(columns):
  return list(map(lambda x: re.sub(r' \[YR(.*)', '', x), columns))

# %%
data.columns = clean_up_year_columns(data.columns)

# %%
data.head(20)
# Out:
#         1972      1973       1974      1975      1976      1977      1978  \
# 0        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 6        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 8        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 9        NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 10       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 11       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 12       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 13       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 16       NaN       NaN   0.267007       NaN       NaN       NaN       NaN
# 17       NaN       NaN   8.500150       NaN       NaN       NaN       NaN
# 18       NaN       NaN  44.028520       NaN       NaN       NaN       NaN
# 20       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 21       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 23       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 24       NaN       NaN        NaN       NaN       NaN       NaN       NaN
# 29  0.138399  0.145555   0.151152  0.169077  0.156516  0.175329  0.153522
#
#         1979      1980      1981  ...      2001          2002          2003  \
# 0        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 1        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 2        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 4        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 5        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 6        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 8        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 9        NaN       NaN       NaN  ...       NaN           NaN           NaN
# 10       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 11       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 12       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 13       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 16       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 17       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 18       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 20       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 21       NaN       NaN       NaN  ...       NaN  3.559253e+09  3.954791e+09
# 23       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 24       NaN       NaN       NaN  ...       NaN  1.603065e+02  1.710835e+02
# 29  0.155825  0.137298  0.179195  ...  0.184407  6.307904e-02  9.517312e-02
#
#             2004          2005          2006          2007  Country Name  \
# 0            NaN           NaN           NaN  3.769214e+00   Afghanistan
# 1            NaN           NaN           NaN  7.027746e+00   Afghanistan
# 2            NaN           NaN           NaN  8.244887e+00   Afghanistan
# 4            NaN           NaN           NaN  1.293310e+01   Afghanistan
# 5            NaN           NaN           NaN  1.899681e+01   Afghanistan
# 6            NaN           NaN           NaN  2.242306e+01   Afghanistan
# 8            NaN           NaN           NaN  5.205600e-01   Afghanistan
# 9            NaN           NaN           NaN  1.496313e+01   Afghanistan
# 10           NaN           NaN           NaN  1.451376e+01   Afghanistan
# 11           NaN           NaN           NaN  0.000000e+00   Afghanistan
# 12           NaN  1.513216e+01           NaN           NaN   Afghanistan
# 13           NaN  1.670967e+01           NaN           NaN   Afghanistan
# 16           NaN           NaN           NaN           NaN   Afghanistan
# 17           NaN           NaN           NaN           NaN   Afghanistan
# 18           NaN           NaN           NaN           NaN   Afghanistan
# 20           NaN  5.505940e+09           NaN           NaN   Afghanistan
# 21  4.602931e+09  5.505940e+09  6.188622e+09  8.592546e+09   Afghanistan
# 23           NaN  2.214702e+02           NaN           NaN   Afghanistan
# 24  1.916396e+02  2.214702e+02  2.414480e+02  3.261022e+02   Afghanistan
# 29  1.076650e-01  1.311738e-01  1.596206e-01  1.775819e-01   Afghanistan
#
#           Series Code                                        Series Name
# 0         allsi.bi_q1  (%) Benefits held by 1st 20% population - All ...
# 1         allsp.bi_q1  (%) Benefits held by 1st 20% population - All ...
# 2         allsa.bi_q1  (%) Benefits held by 1st 20% population - All ...
# 4       allsi.gen_pop             (%) Generosity of All Social Insurance
# 5       allsp.gen_pop            (%) Generosity of All Social Protection
# 6       allsa.gen_pop           (%) Generosity of All Social Safety Nets
# 8       allsi.cov_pop   (%) Program participation - All Social Insurance
# 9       allsp.cov_pop  (%) Program participation - All Social Protection
# 10      allsa.cov_pop  (%) Program participation - All Social Safety ...
# 11      lm_ub.cov_pop  (%) Program participation - Unemp benefits and...
# 12      PA.NUS.PPP.05  2005 PPP conversion factor, GDP (LCU per inter...
# 13  PA.NUS.PRVT.PP.05  2005 PPP conversion factor, private consumptio...
# 16                2.1                Achieve universal primary education
# 17     SE.PRM.TENR.FE  Adjusted net enrollment rate, primary, female ...
# 18     SE.PRM.TENR.MA  Adjusted net enrollment rate, primary, male (%...
# 20     NY.ADJ.NNTY.KD   Adjusted net national income (constant 2005 US$)
# 21     NY.ADJ.NNTY.CD         Adjusted net national income (current US$)
# 23  NY.ADJ.NNTY.PC.KD  Adjusted net national income per capita (const...
# 24  NY.ADJ.NNTY.PC.CD  Adjusted net national income per capita (curre...
# 29  NY.ADJ.DCO2.GN.ZS  Adjusted savings: carbon dioxide damage (% of ...
#
# [20 rows x 39 columns]

# %%
included_years = list(map(lambda x: str(x), range(1972, 2008)))

# %%
data.columns
# Out:
# Index(['1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        'Country Name', 'Series Code', 'Series Name'],
#       dtype='object')

# %%
data.head()
# Out:
#    1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  ...  2001  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#    2002  2003  2004  2005  2006       2007  Country Name    Series Code  \
# 0   NaN   NaN   NaN   NaN   NaN   3.769214   Afghanistan    allsi.bi_q1
# 1   NaN   NaN   NaN   NaN   NaN   7.027746   Afghanistan    allsp.bi_q1
# 2   NaN   NaN   NaN   NaN   NaN   8.244887   Afghanistan    allsa.bi_q1
# 4   NaN   NaN   NaN   NaN   NaN  12.933105   Afghanistan  allsi.gen_pop
# 5   NaN   NaN   NaN   NaN   NaN  18.996814   Afghanistan  allsp.gen_pop
#
#                                          Series Name
# 0  (%) Benefits held by 1st 20% population - All ...
# 1  (%) Benefits held by 1st 20% population - All ...
# 2  (%) Benefits held by 1st 20% population - All ...
# 4             (%) Generosity of All Social Insurance
# 5            (%) Generosity of All Social Protection
#
# [5 rows x 39 columns]

# %%
pred_data = data.copy()

# %%
submission_series = data.loc[submission_rows.index]['Series Name'].unique()
submission_series
# Out:
# array(['Ensure environmental sustainability',
#        'Develop a global partnership for development: Internet Use',
#        'Reduce child mortality', 'Combat HIV/AIDS',
#        'Achieve universal primary education', 'Improve maternal health',
#        'Combat malaria and other diseases'], dtype=object)

# %%
def get_country_time_series(data, country_name):
    country_data = data[data['Country Name'] == country_name]
    
    time_series = country_data.melt(
        id_vars=['Series Name'], 
        value_vars=included_years, 
        var_name='year', 
        value_name='index'
    ).pivot(index='year', columns='Series Name', values='index')
    
    time_series = time_series.dropna(axis='columns', thresh=4)
    time_series.index = pd.to_datetime(time_series.index)
    time_series = time_series.interpolate(method='slinear', axis=0, limit_direction='both').ffill().bfill()
    
    return time_series

# %%
final_pred_df = None

# %%
# %%capture

for country in data['Country Name'].unique():
    time_series = get_country_time_series(data, country)
    time_series_diffed = time_series.diff().dropna()
    
    selector = VarianceThreshold()
    selector.fit(time_series_diffed)
    selected_columns = time_series_diffed.columns[selector.get_support()]
    time_series_diffed = time_series_diffed[selected_columns]
    
    model = VAR(endog=time_series_diffed)
    model_fit = model.fit()
    five_year_pred = model_fit.forecast(model_fit.endog, steps=5)
    pred_df = pd.DataFrame(five_year_pred)
    pred_df.index = pd.DatetimeIndex(['2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01'], name='year')
    pred_df.columns = selected_columns
    
    new_time_series = pd.concat([time_series.iloc[[0]], time_series_diffed, pred_df])
    new_time_series = new_time_series.apply(np.cumsum)
    
    pred_time_series = new_time_series.tail(5).reset_index()
    melted_pred_time_series = pred_time_series.melt(id_vars='year', var_name='Series Name', value_name='Series index')
    proper_time_series = melted_pred_time_series.pivot(index='Series Name', columns='year', values='Series index').reset_index()
    
    proper_time_series.columns = ['Series Name', '2008', '2009', '2010', '2011', '2012']
    proper_time_series['Country Name'] = country
    final_pred_df = pd.concat([final_pred_df, proper_time_series], ignore_index=True)

# %%
final = pd.merge(
    data,
    final_pred_df, 
    left_on=['Country Name', 'Series Name'], 
    right_on=['Country Name', 'Series Name'], 
    how='outer'
)

# %%
final.index = data.index

# %%
submission_df = final.loc[submission_rows.index].fillna(value=final['2007'])

# %%
submission_df['2008'] = submission_df['2008'].fillna(submission_df['2007'])
submission_df['2012'] = submission_df['2012'].fillna(submission_df['2007'])

# %%
final_submission = submission_df[['2008', '2012']]

# %%
submission_rows.shape
# Out:
# (737, 2)

# %%
final_submission.columns = submission_rows.columns

# %%
final_submission.to_csv('sub.csv')
